# %% [markdown]
# ### Import Modules, Change Directory, Set Variables

# %%
import_location = '/Users/johnmccloskey/Development/opengamedata/jupyter/jowilder_data'
export_location = 'jowilder_graphs'

# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
from datetime import date
import numpy as np

# %%
files = os.listdir(import_location)
tsv_files = [f for f in files if f.endswith('sv')]
print(f"{'-'*5} {os.path.split(import_location)[-1]} {'-'*5}" )
print(*[f'{i}: {f}' for i, f in enumerate(tsv_files)][:10], sep='\n')
# Out:
# ----- jowilder_data -----
# 0: 20200114_assessment_4.tsv
# 1: 20191220_assessment_4.tsv
# 2: 12182019 jowidler assessment 4.tsv

# %%
import_n = 0

# %% [markdown]
# ### Import

# %%
df = pd.read_csv(os.path.join(import_location,tsv_files[import_n]), sep='\t',index_col='sessionID')
print(df.shape)
df.head()
# Out:
# (408, 380)
#                    lvl0_EventCount  lvl0_count_clicks  lvl0_count_hovers  \
# sessionID
# 19110000090781600               34               26.0                6.0
# 19110009114094480               21               18.0                1.0
# 19110009240104090               34               32.0                NaN
# 19110011340239490               44               32.0               10.0
# 19110011550785024                2                NaN                NaN
#
#                    lvl0_avgTimePerTextBox  lvl0_time_in_level  \
# sessionID
# 19110000090781600                1.672167              63.535
# 19110009114094480                1.839250              44.510
# 19110009240104090                4.855400              69.398
# 19110011340239490              100.786833             624.439
# 19110011550785024                     NaN               0.001
#
#                    lvl0_meaningful_action_count  lvl0_words_per_second  \
# sessionID
# 19110000090781600                           3.0               3.970336
# 19110009114094480                           1.0               4.523686
# 19110009240104090                           3.0               2.397087
# 19110011340239490                           4.0               5.998923
# 19110011550785024                           NaN                    NaN
#
#                    lvl0_count_notebook_uses  lvl0_avg_time_between_clicks  \
# sessionID
# 19110000090781600                       NaN                      2.096680
# 19110009114094480                       NaN                      1.195588
# 19110009240104090                       NaN                      1.710000
# 19110011340239490                       NaN                     20.042097
# 19110011550785024                       NaN                           NaN
#
#                    lvl1_EventCount  ...  sess_avgTimePerWord  \
# sessionID                           ...
# 19110000090781600             30.0  ...                    0
# 19110009114094480             27.0  ...                    0
# 19110009240104090             82.0  ...                    0
# 19110011340239490             37.0  ...                    0
# 19110011550785024              NaN  ...                    0
#
#                    sess_avgTimePerTextBox  sess_stDevTimePerTextBox  \
# sessionID
# 19110000090781600               16.005742                         0
# 19110009114094480                7.617183                         0
# 19110009240104090                6.841911                         0
# 19110011340239490               15.915329                         0
# 19110011550785024                3.404938                         0
#
#                    sess_words_per_second  sess_count_notebook_uses  \
# sessionID
# 19110000090781600               4.125283                         8
# 19110009114094480               4.731634                         6
# 19110009240104090               4.913462                        40
# 19110011340239490               9.452699                         2
# 19110011550785024               9.990271                        10
#
#                    sess_avg_time_between_clicks    save_code  music  hq  \
# sessionID
# 19110000090781600                    161.139635            0      1   0
# 19110009114094480                      2.034186  donethework      1   0
# 19110009240104090                      1.220895            0      1   0
# 19110011340239490                      2.603901            0      1   0
# 19110011550785024                      8.605613   backtowork  False   0
#
#                    fullscreen
# sessionID
# 19110000090781600           0
# 19110009114094480           0
# 19110009240104090           0
# 19110011340239490           0
# 19110011550785024           0
#
# [5 rows x 380 columns]

# %%
list(df.columns)
# Out:
# ['lvl0_EventCount',
#  'lvl0_count_clicks',
#  'lvl0_count_hovers',
#  'lvl0_avgTimePerTextBox',
#  'lvl0_time_in_level',
#  'lvl0_meaningful_action_count',
#  'lvl0_words_per_second',
#  'lvl0_count_notebook_uses',
#  'lvl0_avg_time_between_clicks',
#  'lvl1_EventCount',
#  'lvl1_count_clicks',
#  'lvl1_count_hovers',
#  'lvl1_avgTimePerTextBox',
#  'lvl1_time_in_level',
#  'lvl1_meaningful_action_count',
#  'lvl1_words_per_second',
#  'lvl1_count_notebook_uses',
#  'lvl1_avg_time_between_clicks',
#  'lvl2_EventCount',
#  'lvl2_count_clicks',
#  'lvl2_count_hovers',
#  'lvl2_avgTimePerTextBox',
#  'lvl2_time_in_level',
#  'lvl2_meaningful_action_count',
#  'lvl2_words_per_second',
#  'lvl2_count_notebook_uses',
#  'lvl2_avg_time_between_clicks',
#  'lvl3_EventCount',
#  'lvl3_count_clicks',
#  'lvl3_count_hovers',
#  'lvl3_avgTimePerTextBox',
#  'lvl3_time_in_level',
#  'lvl3_meaningful_action_count',
#  'lvl3_words_per_second',
#  'lvl3_count_notebook_uses',
#  'lvl3_avg_time_between_clicks',
#  'lvl4_EventCount',
#  'lvl4_count_clicks',
#  'lvl4_count_hovers',
#  'lvl4_avgTimePerTextBox',
#  'lvl4_time_in_level',
#  'lvl4_meaningful_action_count',
#  'lvl4_words_per_second',
#  'lvl4_count_notebook_uses',
#  'lvl4_avg_time_between_clicks',
#  'lvl5_EventCount',
#  'lvl5_count_clicks',
#  'lvl5_count_hovers',
#  'lvl5_avgTimePerTextBox',
#  'lvl5_time_in_level',
#  'lvl5_meaningful_action_count',
#  'lvl5_words_per_second',
#  'lvl5_count_notebook_uses',
#  'lvl5_avg_time_between_clicks',
#  'lvl6_EventCount',
#  'lvl6_count_clicks',
#  'lvl6_count_hovers',
#  'lvl6_avgTimePerTextBox',
#  'lvl6_time_in_level',
#  'lvl6_meaningful_action_count',
#  'lvl6_words_per_second',
#  'lvl6_count_notebook_uses',
#  'lvl6_avg_time_between_clicks',
#  'lvl7_EventCount',
#  'lvl7_count_clicks',
#  'lvl7_count_hovers',
#  'lvl7_avgTimePerTextBox',
#  'lvl7_time_in_level',
#  'lvl7_meaningful_action_count',
#  'lvl7_words_per_second',
#  'lvl7_count_notebook_uses',
#  'lvl7_avg_time_between_clicks',
#  'lvl8_EventCount',
#  'lvl8_count_clicks',
#  'lvl8_count_hovers',
#  'lvl8_avgTimePerTextBox',
#  'lvl8_time_in_level',
#  'lvl8_meaningful_action_count',
#  'lvl8_words_per_second',
#  'lvl8_count_notebook_uses',
#  'lvl8_avg_time_between_clicks',
#  'lvl9_EventCount',
#  'lvl9_count_clicks',
#  'lvl9_count_hovers',
#  'lvl9_avgTimePerTextBox',
#  'lvl9_time_in_level',
#  'lvl9_meaningful_action_count',
#  'lvl9_words_per_second',
#  'lvl9_count_notebook_uses',
#  'lvl9_avg_time_between_clicks',
#  'lvl10_EventCount',
#  'lvl10_count_clicks',
#  'lvl10_count_hovers',
#  'lvl10_avgTimePerTextBox',
#  'lvl10_time_in_level',
#  'lvl10_meaningful_action_count',
#  'lvl10_words_per_second',
#  'lvl10_count_notebook_uses',
#  'lvl10_avg_time_between_clicks',
#  'lvl11_EventCount',
#  'lvl11_count_clicks',
#  'lvl11_count_hovers',
#  'lvl11_avgTimePerTextBox',
#  'lvl11_time_in_level',
#  'lvl11_meaningful_action_count',
#  'lvl11_words_per_second',
#  'lvl11_count_notebook_uses',
#  'lvl11_avg_time_between_clicks',
#  'lvl12_EventCount',
#  'lvl12_count_clicks',
#  'lvl12_count_hovers',
#  'lvl12_avgTimePerTextBox',
#  'lvl12_time_in_level',
#  'lvl12_meaningful_action_count',
#  'lvl12_words_per_second',
#  'lvl12_count_notebook_uses',
#  'lvl12_avg_time_between_clicks',
#  'lvl13_EventCount',
#  'lvl13_count_clicks',
#  'lvl13_count_hovers',
#  'lvl13_avgTimePerTextBox',
#  'lvl13_time_in_level',
#  'lvl13_meaningful_action_count',
#  'lvl13_words_per_second',
#  'lvl13_count_notebook_uses',
#  'lvl13_avg_time_between_clicks',
#  'lvl14_EventCount',
#  'lvl14_count_clicks',
#  'lvl14_count_hovers',
#  'lvl14_avgTimePerTextBox',
#  'lvl14_time_in_level',
#  'lvl14_meaningful_action_count',
#  'lvl14_words_per_second',
#  'lvl14_count_notebook_uses',
#  'lvl14_avg_time_between_clicks',
#  'lvl15_EventCount',
#  'lvl15_count_clicks',
#  'lvl15_count_hovers',
#  'lvl15_avgTimePerTextBox',
#  'lvl15_time_in_level',
#  'lvl15_meaningful_action_count',
#  'lvl15_words_per_second',
#  'lvl15_count_notebook_uses',
#  'lvl15_avg_time_between_clicks',
#  'lvl16_EventCount',
#  'lvl16_count_clicks',
#  'lvl16_count_hovers',
#  'lvl16_avgTimePerTextBox',
#  'lvl16_time_in_level',
#  'lvl16_meaningful_action_count',
#  'lvl16_words_per_second',
#  'lvl16_count_notebook_uses',
#  'lvl16_avg_time_between_clicks',
#  'lvl17_EventCount',
#  'lvl17_count_clicks',
#  'lvl17_count_hovers',
#  'lvl17_avgTimePerTextBox',
#  'lvl17_time_in_level',
#  'lvl17_meaningful_action_count',
#  'lvl17_words_per_second',
#  'lvl17_count_notebook_uses',
#  'lvl17_avg_time_between_clicks',
#  'lvl18_EventCount',
#  'lvl18_count_clicks',
#  'lvl18_count_hovers',
#  'lvl18_avgTimePerTextBox',
#  'lvl18_time_in_level',
#  'lvl18_meaningful_action_count',
#  'lvl18_words_per_second',
#  'lvl18_count_notebook_uses',
#  'lvl18_avg_time_between_clicks',
#  'lvl19_EventCount',
#  'lvl19_count_clicks',
#  'lvl19_count_hovers',
#  'lvl19_avgTimePerTextBox',
#  'lvl19_time_in_level',
#  'lvl19_meaningful_action_count',
#  'lvl19_words_per_second',
#  'lvl19_count_notebook_uses',
#  'lvl19_avg_time_between_clicks',
#  'lvl20_EventCount',
#  'lvl20_count_clicks',
#  'lvl20_count_hovers',
#  'lvl20_avgTimePerTextBox',
#  'lvl20_time_in_level',
#  'lvl20_meaningful_action_count',
#  'lvl20_words_per_second',
#  'lvl20_count_notebook_uses',
#  'lvl20_avg_time_between_clicks',
#  'lvl21_EventCount',
#  'lvl21_count_clicks',
#  'lvl21_count_hovers',
#  'lvl21_avgTimePerTextBox',
#  'lvl21_time_in_level',
#  'lvl21_meaningful_action_count',
#  'lvl21_words_per_second',
#  'lvl21_count_notebook_uses',
#  'lvl21_avg_time_between_clicks',
#  'lvl22_EventCount',
#  'lvl22_count_clicks',
#  'lvl22_count_hovers',
#  'lvl22_avgTimePerTextBox',
#  'lvl22_time_in_level',
#  'lvl22_meaningful_action_count',
#  'lvl22_words_per_second',
#  'lvl22_count_notebook_uses',
#  'lvl22_avg_time_between_clicks',
#  'Q0_num_guesses',
#  'Q1_num_guesses',
#  'Q2_num_guesses',
#  'Q3_num_guesses',
#  'Q4_num_guesses',
#  'Q5_num_guesses',
#  'Q6_num_guesses',
#  'Q7_num_guesses',
#  'Q8_num_guesses',
#  'Q9_num_guesses',
#  'Q10_num_guesses',
#  'Q11_num_guesses',
#  'Q12_num_guesses',
#  'Q13_num_guesses',
#  'Q14_num_guesses',
#  'Q15_num_guesses',
#  'Q16_num_guesses',
#  'Q17_num_guesses',
#  'Q18_num_guesses',
#  'Q0_answers',
#  'Q1_answers',
#  'Q2_answers',
#  'Q3_answers',
#  'Q4_answers',
#  'Q5_answers',
#  'Q6_answers',
#  'Q7_answers',
#  'Q8_answers',
#  'Q9_answers',
#  'Q10_answers',
#  'Q11_answers',
#  'Q12_answers',
#  'Q13_answers',
#  'Q14_answers',
#  'Q15_answers',
#  'Q16_answers',
#  'Q17_answers',
#  'Q18_answers',
#  'Q0_A1',
#  'Q1_A1',
#  'Q2_A1',
#  'Q3_A1',
#  'Q4_A1',
#  'Q5_A1',
#  'Q6_A1',
#  'Q7_A1',
#  'Q8_A1',
#  'Q9_A1',
#  'Q10_A1',
#  'Q11_A1',
#  'Q12_A1',
#  'Q13_A1',
#  'Q14_A1',
#  'Q15_A1',
#  'Q16_A1',
#  'Q17_A1',
#  'Q18_A1',
#  'Q0_A2',
#  'Q1_A2',
#  'Q2_A2',
#  'Q3_A2',
#  'Q4_A2',
#  'Q5_A2',
#  'Q6_A2',
#  'Q7_A2',
#  'Q8_A2',
#  'Q9_A2',
#  'Q10_A2',
#  'Q11_A2',
#  'Q12_A2',
#  'Q13_A2',
#  'Q14_A2',
#  'Q15_A2',
#  'Q16_A2',
#  'Q17_A2',
#  'Q18_A2',
#  'Q0_A3',
#  'Q1_A3',
#  'Q2_A3',
#  'Q3_A3',
#  'Q4_A3',
#  'Q5_A3',
#  'Q6_A3',
#  'Q7_A3',
#  'Q8_A3',
#  'Q9_A3',
#  'Q10_A3',
#  'Q11_A3',
#  'Q12_A3',
#  'Q13_A3',
#  'Q14_A3',
#  'Q15_A3',
#  'Q16_A3',
#  'Q17_A3',
#  'Q18_A3',
#  'Q0_A1_time',
#  'Q1_A1_time',
#  'Q2_A1_time',
#  'Q3_A1_time',
#  'Q4_A1_time',
#  'Q5_A1_time',
#  'Q6_A1_time',
#  'Q7_A1_time',
#  'Q8_A1_time',
#  'Q9_A1_time',
#  'Q10_A1_time',
#  'Q11_A1_time',
#  'Q12_A1_time',
#  'Q13_A1_time',
#  'Q14_A1_time',
#  'Q15_A1_time',
#  'Q16_A1_time',
#  'Q17_A1_time',
#  'Q18_A1_time',
#  'Q0_A2_time',
#  'Q1_A2_time',
#  'Q2_A2_time',
#  'Q3_A2_time',
#  'Q4_A2_time',
#  'Q5_A2_time',
#  'Q6_A2_time',
#  'Q7_A2_time',
#  'Q8_A2_time',
#  'Q9_A2_time',
#  'Q10_A2_time',
#  'Q11_A2_time',
#  'Q12_A2_time',
#  'Q13_A2_time',
#  'Q14_A2_time',
#  'Q15_A2_time',
#  'Q16_A2_time',
#  'Q17_A2_time',
#  'Q18_A2_time',
#  'Q0_A3_time',
#  'Q1_A3_time',
#  'Q2_A3_time',
#  'Q3_A3_time',
#  'Q4_A3_time',
#  'Q5_A3_time',
#  'Q6_A3_time',
#  'Q7_A3_time',
#  'Q8_A3_time',
#  'Q9_A3_time',
#  'Q10_A3_time',
#  'Q11_A3_time',
#  'Q12_A3_time',
#  'Q13_A3_time',
#  'Q14_A3_time',
#  'Q15_A3_time',
#  'Q16_A3_time',
#  'Q17_A3_time',
#  'Q18_A3_time',
#  'R0_quiz_response',
#  'R1_quiz_response',
#  'R2_quiz_response',
#  'persistentSessionID',
#  'max_level',
#  'sessDuration',
#  'sess_count_clicks',
#  'sess_count_hovers',
#  'sess_meaningful_action_count',
#  'sess_EventCount',
#  'sess_timeToRead',
#  'sess_avgTimePerWord',
#  'sess_avgTimePerTextBox',
#  'sess_stDevTimePerTextBox',
#  'sess_words_per_second',
#  'sess_count_notebook_uses',
#  'sess_avg_time_between_clicks',
#  'save_code',
#  'music',
#  'hq',
#  'fullscreen']

# %% [markdown]
# ### Drop Rows with save_codes (continues) or no answers

# %%
df = df.drop(df[df['save_code'] != '0'].index)
print(df.shape)
answer_cols = [ 'R0_quiz_response','R1_quiz_response','R2_quiz_response']
for c in answer_cols:
    df[c] = df[c].astype(int)
    df = df.drop(df[df[c] == -1].index)
print(df.shape)
df[answer_cols].head()
# Out:
# (346, 380)
# (153, 380)
#                    R0_quiz_response  R1_quiz_response  R2_quiz_response
# sessionID
# 19110000090781600                 0                 1                 1
# 19110009240104090                 0                 2                 0
# 19110011340239490                 0                 2                 2
# 19110012454548376                 1                 2                 3
# 19110015213957736                 0                 2                 0

# %%
df.dropna(subset=['lvl0_EventCount'])
list(df.columns)
# Out:
# ['lvl0_EventCount',
#  'lvl0_count_clicks',
#  'lvl0_count_hovers',
#  'lvl0_avgTimePerTextBox',
#  'lvl0_time_in_level',
#  'lvl0_meaningful_action_count',
#  'lvl0_words_per_second',
#  'lvl0_count_notebook_uses',
#  'lvl0_avg_time_between_clicks',
#  'lvl1_EventCount',
#  'lvl1_count_clicks',
#  'lvl1_count_hovers',
#  'lvl1_avgTimePerTextBox',
#  'lvl1_time_in_level',
#  'lvl1_meaningful_action_count',
#  'lvl1_words_per_second',
#  'lvl1_count_notebook_uses',
#  'lvl1_avg_time_between_clicks',
#  'lvl2_EventCount',
#  'lvl2_count_clicks',
#  'lvl2_count_hovers',
#  'lvl2_avgTimePerTextBox',
#  'lvl2_time_in_level',
#  'lvl2_meaningful_action_count',
#  'lvl2_words_per_second',
#  'lvl2_count_notebook_uses',
#  'lvl2_avg_time_between_clicks',
#  'lvl3_EventCount',
#  'lvl3_count_clicks',
#  'lvl3_count_hovers',
#  'lvl3_avgTimePerTextBox',
#  'lvl3_time_in_level',
#  'lvl3_meaningful_action_count',
#  'lvl3_words_per_second',
#  'lvl3_count_notebook_uses',
#  'lvl3_avg_time_between_clicks',
#  'lvl4_EventCount',
#  'lvl4_count_clicks',
#  'lvl4_count_hovers',
#  'lvl4_avgTimePerTextBox',
#  'lvl4_time_in_level',
#  'lvl4_meaningful_action_count',
#  'lvl4_words_per_second',
#  'lvl4_count_notebook_uses',
#  'lvl4_avg_time_between_clicks',
#  'lvl5_EventCount',
#  'lvl5_count_clicks',
#  'lvl5_count_hovers',
#  'lvl5_avgTimePerTextBox',
#  'lvl5_time_in_level',
#  'lvl5_meaningful_action_count',
#  'lvl5_words_per_second',
#  'lvl5_count_notebook_uses',
#  'lvl5_avg_time_between_clicks',
#  'lvl6_EventCount',
#  'lvl6_count_clicks',
#  'lvl6_count_hovers',
#  'lvl6_avgTimePerTextBox',
#  'lvl6_time_in_level',
#  'lvl6_meaningful_action_count',
#  'lvl6_words_per_second',
#  'lvl6_count_notebook_uses',
#  'lvl6_avg_time_between_clicks',
#  'lvl7_EventCount',
#  'lvl7_count_clicks',
#  'lvl7_count_hovers',
#  'lvl7_avgTimePerTextBox',
#  'lvl7_time_in_level',
#  'lvl7_meaningful_action_count',
#  'lvl7_words_per_second',
#  'lvl7_count_notebook_uses',
#  'lvl7_avg_time_between_clicks',
#  'lvl8_EventCount',
#  'lvl8_count_clicks',
#  'lvl8_count_hovers',
#  'lvl8_avgTimePerTextBox',
#  'lvl8_time_in_level',
#  'lvl8_meaningful_action_count',
#  'lvl8_words_per_second',
#  'lvl8_count_notebook_uses',
#  'lvl8_avg_time_between_clicks',
#  'lvl9_EventCount',
#  'lvl9_count_clicks',
#  'lvl9_count_hovers',
#  'lvl9_avgTimePerTextBox',
#  'lvl9_time_in_level',
#  'lvl9_meaningful_action_count',
#  'lvl9_words_per_second',
#  'lvl9_count_notebook_uses',
#  'lvl9_avg_time_between_clicks',
#  'lvl10_EventCount',
#  'lvl10_count_clicks',
#  'lvl10_count_hovers',
#  'lvl10_avgTimePerTextBox',
#  'lvl10_time_in_level',
#  'lvl10_meaningful_action_count',
#  'lvl10_words_per_second',
#  'lvl10_count_notebook_uses',
#  'lvl10_avg_time_between_clicks',
#  'lvl11_EventCount',
#  'lvl11_count_clicks',
#  'lvl11_count_hovers',
#  'lvl11_avgTimePerTextBox',
#  'lvl11_time_in_level',
#  'lvl11_meaningful_action_count',
#  'lvl11_words_per_second',
#  'lvl11_count_notebook_uses',
#  'lvl11_avg_time_between_clicks',
#  'lvl12_EventCount',
#  'lvl12_count_clicks',
#  'lvl12_count_hovers',
#  'lvl12_avgTimePerTextBox',
#  'lvl12_time_in_level',
#  'lvl12_meaningful_action_count',
#  'lvl12_words_per_second',
#  'lvl12_count_notebook_uses',
#  'lvl12_avg_time_between_clicks',
#  'lvl13_EventCount',
#  'lvl13_count_clicks',
#  'lvl13_count_hovers',
#  'lvl13_avgTimePerTextBox',
#  'lvl13_time_in_level',
#  'lvl13_meaningful_action_count',
#  'lvl13_words_per_second',
#  'lvl13_count_notebook_uses',
#  'lvl13_avg_time_between_clicks',
#  'lvl14_EventCount',
#  'lvl14_count_clicks',
#  'lvl14_count_hovers',
#  'lvl14_avgTimePerTextBox',
#  'lvl14_time_in_level',
#  'lvl14_meaningful_action_count',
#  'lvl14_words_per_second',
#  'lvl14_count_notebook_uses',
#  'lvl14_avg_time_between_clicks',
#  'lvl15_EventCount',
#  'lvl15_count_clicks',
#  'lvl15_count_hovers',
#  'lvl15_avgTimePerTextBox',
#  'lvl15_time_in_level',
#  'lvl15_meaningful_action_count',
#  'lvl15_words_per_second',
#  'lvl15_count_notebook_uses',
#  'lvl15_avg_time_between_clicks',
#  'lvl16_EventCount',
#  'lvl16_count_clicks',
#  'lvl16_count_hovers',
#  'lvl16_avgTimePerTextBox',
#  'lvl16_time_in_level',
#  'lvl16_meaningful_action_count',
#  'lvl16_words_per_second',
#  'lvl16_count_notebook_uses',
#  'lvl16_avg_time_between_clicks',
#  'lvl17_EventCount',
#  'lvl17_count_clicks',
#  'lvl17_count_hovers',
#  'lvl17_avgTimePerTextBox',
#  'lvl17_time_in_level',
#  'lvl17_meaningful_action_count',
#  'lvl17_words_per_second',
#  'lvl17_count_notebook_uses',
#  'lvl17_avg_time_between_clicks',
#  'lvl18_EventCount',
#  'lvl18_count_clicks',
#  'lvl18_count_hovers',
#  'lvl18_avgTimePerTextBox',
#  'lvl18_time_in_level',
#  'lvl18_meaningful_action_count',
#  'lvl18_words_per_second',
#  'lvl18_count_notebook_uses',
#  'lvl18_avg_time_between_clicks',
#  'lvl19_EventCount',
#  'lvl19_count_clicks',
#  'lvl19_count_hovers',
#  'lvl19_avgTimePerTextBox',
#  'lvl19_time_in_level',
#  'lvl19_meaningful_action_count',
#  'lvl19_words_per_second',
#  'lvl19_count_notebook_uses',
#  'lvl19_avg_time_between_clicks',
#  'lvl20_EventCount',
#  'lvl20_count_clicks',
#  'lvl20_count_hovers',
#  'lvl20_avgTimePerTextBox',
#  'lvl20_time_in_level',
#  'lvl20_meaningful_action_count',
#  'lvl20_words_per_second',
#  'lvl20_count_notebook_uses',
#  'lvl20_avg_time_between_clicks',
#  'lvl21_EventCount',
#  'lvl21_count_clicks',
#  'lvl21_count_hovers',
#  'lvl21_avgTimePerTextBox',
#  'lvl21_time_in_level',
#  'lvl21_meaningful_action_count',
#  'lvl21_words_per_second',
#  'lvl21_count_notebook_uses',
#  'lvl21_avg_time_between_clicks',
#  'lvl22_EventCount',
#  'lvl22_count_clicks',
#  'lvl22_count_hovers',
#  'lvl22_avgTimePerTextBox',
#  'lvl22_time_in_level',
#  'lvl22_meaningful_action_count',
#  'lvl22_words_per_second',
#  'lvl22_count_notebook_uses',
#  'lvl22_avg_time_between_clicks',
#  'Q0_num_guesses',
#  'Q1_num_guesses',
#  'Q2_num_guesses',
#  'Q3_num_guesses',
#  'Q4_num_guesses',
#  'Q5_num_guesses',
#  'Q6_num_guesses',
#  'Q7_num_guesses',
#  'Q8_num_guesses',
#  'Q9_num_guesses',
#  'Q10_num_guesses',
#  'Q11_num_guesses',
#  'Q12_num_guesses',
#  'Q13_num_guesses',
#  'Q14_num_guesses',
#  'Q15_num_guesses',
#  'Q16_num_guesses',
#  'Q17_num_guesses',
#  'Q18_num_guesses',
#  'Q0_answers',
#  'Q1_answers',
#  'Q2_answers',
#  'Q3_answers',
#  'Q4_answers',
#  'Q5_answers',
#  'Q6_answers',
#  'Q7_answers',
#  'Q8_answers',
#  'Q9_answers',
#  'Q10_answers',
#  'Q11_answers',
#  'Q12_answers',
#  'Q13_answers',
#  'Q14_answers',
#  'Q15_answers',
#  'Q16_answers',
#  'Q17_answers',
#  'Q18_answers',
#  'Q0_A1',
#  'Q1_A1',
#  'Q2_A1',
#  'Q3_A1',
#  'Q4_A1',
#  'Q5_A1',
#  'Q6_A1',
#  'Q7_A1',
#  'Q8_A1',
#  'Q9_A1',
#  'Q10_A1',
#  'Q11_A1',
#  'Q12_A1',
#  'Q13_A1',
#  'Q14_A1',
#  'Q15_A1',
#  'Q16_A1',
#  'Q17_A1',
#  'Q18_A1',
#  'Q0_A2',
#  'Q1_A2',
#  'Q2_A2',
#  'Q3_A2',
#  'Q4_A2',
#  'Q5_A2',
#  'Q6_A2',
#  'Q7_A2',
#  'Q8_A2',
#  'Q9_A2',
#  'Q10_A2',
#  'Q11_A2',
#  'Q12_A2',
#  'Q13_A2',
#  'Q14_A2',
#  'Q15_A2',
#  'Q16_A2',
#  'Q17_A2',
#  'Q18_A2',
#  'Q0_A3',
#  'Q1_A3',
#  'Q2_A3',
#  'Q3_A3',
#  'Q4_A3',
#  'Q5_A3',
#  'Q6_A3',
#  'Q7_A3',
#  'Q8_A3',
#  'Q9_A3',
#  'Q10_A3',
#  'Q11_A3',
#  'Q12_A3',
#  'Q13_A3',
#  'Q14_A3',
#  'Q15_A3',
#  'Q16_A3',
#  'Q17_A3',
#  'Q18_A3',
#  'Q0_A1_time',
#  'Q1_A1_time',
#  'Q2_A1_time',
#  'Q3_A1_time',
#  'Q4_A1_time',
#  'Q5_A1_time',
#  'Q6_A1_time',
#  'Q7_A1_time',
#  'Q8_A1_time',
#  'Q9_A1_time',
#  'Q10_A1_time',
#  'Q11_A1_time',
#  'Q12_A1_time',
#  'Q13_A1_time',
#  'Q14_A1_time',
#  'Q15_A1_time',
#  'Q16_A1_time',
#  'Q17_A1_time',
#  'Q18_A1_time',
#  'Q0_A2_time',
#  'Q1_A2_time',
#  'Q2_A2_time',
#  'Q3_A2_time',
#  'Q4_A2_time',
#  'Q5_A2_time',
#  'Q6_A2_time',
#  'Q7_A2_time',
#  'Q8_A2_time',
#  'Q9_A2_time',
#  'Q10_A2_time',
#  'Q11_A2_time',
#  'Q12_A2_time',
#  'Q13_A2_time',
#  'Q14_A2_time',
#  'Q15_A2_time',
#  'Q16_A2_time',
#  'Q17_A2_time',
#  'Q18_A2_time',
#  'Q0_A3_time',
#  'Q1_A3_time',
#  'Q2_A3_time',
#  'Q3_A3_time',
#  'Q4_A3_time',
#  'Q5_A3_time',
#  'Q6_A3_time',
#  'Q7_A3_time',
#  'Q8_A3_time',
#  'Q9_A3_time',
#  'Q10_A3_time',
#  'Q11_A3_time',
#  'Q12_A3_time',
#  'Q13_A3_time',
#  'Q14_A3_time',
#  'Q15_A3_time',
#  'Q16_A3_time',
#  'Q17_A3_time',
#  'Q18_A3_time',
#  'R0_quiz_response',
#  'R1_quiz_response',
#  'R2_quiz_response',
#  'persistentSessionID',
#  'max_level',
#  'sessDuration',
#  'sess_count_clicks',
#  'sess_count_hovers',
#  'sess_meaningful_action_count',
#  'sess_EventCount',
#  'sess_timeToRead',
#  'sess_avgTimePerWord',
#  'sess_avgTimePerTextBox',
#  'sess_stDevTimePerTextBox',
#  'sess_words_per_second',
#  'sess_count_notebook_uses',
#  'sess_avg_time_between_clicks',
#  'save_code',
#  'music',
#  'hq',
#  'fullscreen']

# %%
df['R0_quiz_response'].head()
# Out:
# sessionID
# 19110000090781600    0
# 19110009240104090    0
# 19110011340239490    0
# 19110012454548376    1
# 19110015213957736    0
# Name: R0_quiz_response, dtype: int64

# %%
answer_labels = [('Yes','No'),('Not a Very Good Reader', 'OK Reader','Very Good Reader'),('Really Enjoy Reading', 'Enjoy Reading',"Reading's Okay","Do Not Enjoy Reading")]
titles = ['English First Language', 'Reading Skill', 'Reading Enjoyment']
def scatter(x_axis_feat, y_axis_feat, xlabel, ylabel,label=None, legend_labels=None, title=None, colors=None, **kwargs):
    label = label or 'R1_quiz_response'
    colors = np.array(colors) or np.array(["red", "green","blue","yellow"])
    tdf = df.dropna(subset=[x_axis_feat, y_axis_feat])
    for ans,label_name, color in zip([0,1,2,3],legend_labels, colors):
        plot_df = tdf[tdf[label] == ans]
        title = title or f'{y_axis_feat} vs. {x_axis_feat} (n={len(tdf)})'
        scatter = plt.scatter(plot_df[x_axis_feat],plot_df[y_axis_feat],
                     c=color, label=label_name, **kwargs)
        mean_df = plot_df = plot_df.mean()
        plt.scatter(mean_df[x_axis_feat], mean_df[y_axis_feat], c=color, s=100, marker='x')
        plt.xlabel(xlabel)
        plt.title(title)
        plt.ylabel(ylabel)
        plt.legend()
        
def all_question_plots(x_axis_feat, y_axis_feat, xlabel, ylabel,suptitle=None,xlim=None, **kwargs):
    fig = plt.figure(figsize=(20,7),dpi=160)
    suptitle = suptitle or f'{y_axis_feat} vs {x_axis_feat}'
    if suptitle:
        fig.suptitle(suptitle,fontsize=24)
    for q in range(3):
        fig.add_subplot(1,3,q+1)
        label = f'R{q}_quiz_response'
        legend_labels = answer_labels[q]
        scatter(x_axis_feat,y_axis_feat, xlabel, ylabel,label=label, legend_labels=legend_labels, title=titles[q],**kwargs)
        if xlim:
            plt.xlim(xlim)
    output_file = os.path.join('jowilder_graphs', f'{date.today().strftime("%Y%m%d")}_{y_axis_feat} vs {x_axis_feat}.jpg')
    fig.savefig(output_file)
assess_1_guesses = [f'Q{i}_num_guesses' for i in range(4)]
df['assess_1_tot_guesses'] = df[assess_1_guesses].sum(axis=1)
df['time_ch1'] = df[[f'lvl{i}_time_in_level' for i in range(5)]].sum(axis=1)
df['time_lvl4_relative_to_total_ch1_time'] = df['lvl4_time_in_level'] / df['time_ch1']*100
                               
all_question_plots('assess_1_tot_guesses','time_lvl4_relative_to_total_ch1_time','Total Guesses Assessment 1', 'Percent Ch1 time spent in lvl4')
df['assess_1_tot_guesses'].head()
# Out:
# sessionID
# 19110000090781600    3.0
# 19110009240104090    3.0
# 19110011340239490    3.0
# 19110012454548376    4.0
# 19110015213957736    3.0
# Name: assess_1_tot_guesses, dtype: float64
