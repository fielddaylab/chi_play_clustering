# %% [markdown]
# ### Import Modules, Change Directory, Set Variables

# %%
import_dir = 'data/filtered data'
export_dir = 'graphs'

# %%
import os
import matplotlib.pyplot as plt
import pandas as pd
from scipy import stats
from datetime import date
import numpy as np

# %%
files = os.listdir(import_dir)
tsv_files = [f for f in files if f.endswith('sv')]
print(f"{'-'*5} {os.path.split(import_dir)[-1]} {'-'*5}" )
print(*[f'{i}: {f}' for i, f in enumerate(tsv_files)][:10], sep='\n')
# Out:
# ----- filtered data -----
# 0: LAKELAND_through_window_3_20200114.tsv

# %%
import_n = 0

# %% [markdown]
# ### Import

# %%
df = pd.read_csv(os.path.join(import_dir,tsv_files[import_n]), sep='\t',index_col='sessID')
print(df.shape)
df.head()
# Out:
# (17116, 651)
#                    lvl0_EventCount  lvl0_ActiveEventCount  \
# sessID
# 19110002150060536              133                   77.0
# 19110007194177108               91                   51.0
# 19110007194177108              184                   50.0
# 19110008292229944              118                   37.0
# 19110008450097140              272                   42.0
#
#                    lvl0_durationInSecs  lvl0_count_gamestate_logs  \
# sessID
# 19110002150060536                  NaN                        4.0
# 19110007194177108                  NaN                        3.0
# 19110007194177108                  NaN                       10.0
# 19110008292229944                  NaN                        6.0
# 19110008450097140                  NaN                        7.0
#
#                    lvl0_count_achievements  lvl0_count_buy_home  \
# sessID
# 19110002150060536                      2.0                  1.0
# 19110007194177108                      2.0                  1.0
# 19110007194177108                      5.0                  2.0
# 19110008292229944                      2.0                  1.0
# 19110008450097140                      4.0                  NaN
#
#                    lvl0_count_buy_food  lvl0_count_buy_farm  \
# sessID
# 19110002150060536                  1.0                  1.0
# 19110007194177108                  1.0                  1.0
# 19110007194177108                  4.0                  NaN
# 19110008292229944                  1.0                  2.0
# 19110008450097140                  NaN                  1.0
#
#                    lvl0_count_buy_fertilizer  lvl0_count_buy_livestock  ...  \
# sessID                                                                  ...
# 19110002150060536                        1.0                       NaN  ...
# 19110007194177108                        NaN                       NaN  ...
# 19110007194177108                        NaN                       NaN  ...
# 19110008292229944                        1.0                       1.0  ...
# 19110008450097140                        4.0                       1.0  ...
#
#                    sess_ActiveEventCount  continue  language  audio  \
# sessID
# 19110002150060536                    197         0   english      1
# 19110007194177108                    149         0   english      1
# 19110007194177108                     50         1   english      1
# 19110008292229944                    150         0   english      1
# 19110008450097140                     65         1   english      1
#
#                    fullscreen  version  debug  num_play  persistentSessionID  \
# sessID
# 19110002150060536           0       15      0         1    19110002150060536
# 19110007194177108           0       15      0         1    19110007194177108
# 19110007194177108           0       15      0         2    19110007194177108
# 19110008292229944           0       15      0         1    19110008292229944
# 19110008450097140           0       15      0         1    19100309270560400
#
#                    sessDuration
# sessID
# 19110002150060536       705.210
# 19110007194177108       674.433
# 19110007194177108       246.690
# 19110008292229944       857.575
# 19110008450097140       677.492
#
# [5 rows x 651 columns]

# %%
list(df.columns)
# Out:
# ['lvl0_EventCount',
#  'lvl0_ActiveEventCount',
#  'lvl0_durationInSecs',
#  'lvl0_count_gamestate_logs',
#  'lvl0_count_achievements',
#  'lvl0_count_buy_home',
#  'lvl0_count_buy_food',
#  'lvl0_count_buy_farm',
#  'lvl0_count_buy_fertilizer',
#  'lvl0_count_buy_livestock',
#  'lvl0_count_buy_skimmer',
#  'lvl0_count_buy_sign',
#  'lvl0_count_buy_road',
#  'lvl0_money_spent',
#  'lvl0_money_spent_home',
#  'lvl0_money_spent_food',
#  'lvl0_money_spent_farm',
#  'lvl0_money_spent_fertilizer',
#  'lvl0_money_spent_livestock',
#  'lvl0_money_spent_skimmer',
#  'lvl0_money_spent_sign',
#  'lvl0_money_spent_road',
#  'lvl0_min_num_home_in_play',
#  'lvl0_max_num_home_in_play',
#  'lvl0_min_num_food_in_play',
#  'lvl0_max_num_food_in_play',
#  'lvl0_min_num_farm_in_play',
#  'lvl0_max_num_farm_in_play',
#  'lvl0_min_num_fertilizer_in_play',
#  'lvl0_max_num_fertilizer_in_play',
#  'lvl0_min_num_livestock_in_play',
#  'lvl0_max_num_livestock_in_play',
#  'lvl0_min_num_skimmer_in_play',
#  'lvl0_max_num_skimmer_in_play',
#  'lvl0_min_num_sign_in_play',
#  'lvl0_max_num_sign_in_play',
#  'lvl0_min_num_road_in_play',
#  'lvl0_max_num_road_in_play',
#  'lvl0_min_num_water_in_play',
#  'lvl0_max_num_water_in_play',
#  'lvl0_min_num_poop_in_play',
#  'lvl0_max_num_poop_in_play',
#  'lvl0_min_num_milk_in_play',
#  'lvl0_max_num_milk_in_play',
#  'lvl0_avg_num_tiles_hovered_before_placing_home',
#  'lvl0_avg_num_tiles_hovered_before_placing_food',
#  'lvl0_avg_num_tiles_hovered_before_placing_farm',
#  'lvl0_avg_num_tiles_hovered_before_placing_fertilizer',
#  'lvl0_avg_num_tiles_hovered_before_placing_livestock',
#  'lvl0_avg_num_tiles_hovered_before_placing_skimmer',
#  'lvl0_avg_num_tiles_hovered_before_placing_sign',
#  'lvl0_avg_num_tiles_hovered_before_placing_road',
#  'lvl0_percent_compliance_with_a_tutorial_within_x_seconds',
#  'lvl0_avg_distance_between_poop_placement_and_lake',
#  'lvl0_avg_avg_distance_between_buildings',
#  'lvl0_percent_building_a_farm_on_highest_nutrition_tile',
#  'lvl0_percent_placing_fertilizer_on_lowest_nutrient_farm',
#  'lvl0_build_sequences',
#  'lvl0_count_inspect_tile',
#  'lvl0_count_open_achievements',
#  'lvl0_count_open_shop',
#  'lvl0_count_deaths',
#  'lvl0_count_encounter_tutorial',
#  'lvl0_count_skips',
#  'lvl0_avg_time_per_blurb',
#  'lvl0_time_in_nutrition_view',
#  'lvl0_time_in_game_speed_pause',
#  'lvl0_time_in_game_speed_play',
#  'lvl0_time_in_game_speed_fast',
#  'lvl0_time_in_game_speed_vfast',
#  'lvl0_count_change_item_mark',
#  'lvl0_count_change_tile_mark',
#  'lvl0_max_num_food_marked_sell',
#  'lvl0_max_num_food_marked_use',
#  'lvl0_max_num_food_marked_feed',
#  'lvl0_max_num_milk_marked_sell',
#  'lvl0_max_num_milk_marked_use',
#  'lvl0_max_num_poop_marked_sell',
#  'lvl0_max_num_poop_marked_use',
#  'lvl0_max_percent_food_marked_sell',
#  'lvl0_max_percent_food_marked_use',
#  'lvl0_max_percent_food_marked_feed',
#  'lvl0_max_percent_milk_marked_sell',
#  'lvl0_max_percent_milk_marked_use',
#  'lvl0_max_percent_poop_marked_sell',
#  'lvl0_max_percent_poop_marked_use',
#  'lvl0_min_num_food_marked_sell',
#  'lvl0_min_num_food_marked_use',
#  'lvl0_min_num_food_marked_feed',
#  'lvl0_min_num_milk_marked_sell',
#  'lvl0_min_num_milk_marked_use',
#  'lvl0_min_num_poop_marked_sell',
#  'lvl0_min_num_poop_marked_use',
#  'lvl0_min_percent_food_marked_sell',
#  'lvl0_min_percent_food_marked_use',
#  'lvl0_min_percent_food_marked_feed',
#  'lvl0_min_percent_milk_marked_sell',
#  'lvl0_min_percent_milk_marked_use',
#  'lvl0_min_percent_poop_marked_sell',
#  'lvl0_min_percent_poop_marked_use',
#  'lvl0_max_num_per_capita_food_marked_sell',
#  'lvl0_min_num_per_capita_food_marked_sell',
#  'lvl0_max_num_per_capita_food_marked_use',
#  'lvl0_min_num_per_capita_food_marked_use',
#  'lvl0_max_num_per_capita_food_marked_feed',
#  'lvl0_min_num_per_capita_food_marked_feed',
#  'lvl0_max_num_per_capita_milk_marked_sell',
#  'lvl0_min_num_per_capita_milk_marked_sell',
#  'lvl0_max_num_per_capita_milk_marked_use',
#  'lvl0_min_num_per_capita_milk_marked_use',
#  'lvl0_max_num_per_capita_poop_marked_sell',
#  'lvl0_min_num_per_capita_poop_marked_sell',
#  'lvl0_max_num_per_capita_poop_marked_use',
#  'lvl0_min_num_per_capita_poop_marked_use',
#  'lvl0_count_fullness_motivated_txt_emotes_per_capita',
#  'lvl0_count_fullness_desperate_txt_emotes_per_capita',
#  'lvl0_count_energy_desperate_txt_emotes_per_capita',
#  'lvl0_count_joy_motivated_txt_emotes_per_capita',
#  'lvl0_count_joy_desperate_txt_emotes_per_capita',
#  'lvl0_count_puke_txt_emotes_per_capita',
#  'lvl0_count_yum_txt_emotes_per_capita',
#  'lvl0_count_tired_txt_emotes_per_capita',
#  'lvl0_count_happy_txt_emotes_per_capita',
#  'lvl0_count_swim_txt_emotes_per_capita',
#  'lvl0_count_sale_txt_emotes_per_capita',
#  'lvl0_percent_positive_emotes',
#  'lvl0_percent_negative_emotes',
#  'lvl0_percent_neutral_emotes',
#  'lvl0_money_earned',
#  'lvl0_total_positive_emotes',
#  'lvl0_total_negative_emotes',
#  'lvl0_total_neutral_emotes',
#  'lvl0_max_avg_lake_nutrition',
#  'lvl0_min_avg_lake_nutrition',
#  'lvl0_count_farmfails',
#  'lvl0_count_blooms',
#  'lvl0_max_num_lake_tiles_in_bloom',
#  'lvl0_min_num_lake_tiles_in_bloom',
#  'lvl0_count_food_produced',
#  'lvl0_count_milk_produced',
#  'lvl0_count_poop_produced',
#  'lvl1_EventCount',
#  'lvl1_ActiveEventCount',
#  'lvl1_durationInSecs',
#  'lvl1_count_gamestate_logs',
#  'lvl1_count_achievements',
#  'lvl1_count_buy_home',
#  'lvl1_count_buy_food',
#  'lvl1_count_buy_farm',
#  'lvl1_count_buy_fertilizer',
#  'lvl1_count_buy_livestock',
#  'lvl1_count_buy_skimmer',
#  'lvl1_count_buy_sign',
#  'lvl1_count_buy_road',
#  'lvl1_money_spent',
#  'lvl1_money_spent_home',
#  'lvl1_money_spent_food',
#  'lvl1_money_spent_farm',
#  'lvl1_money_spent_fertilizer',
#  'lvl1_money_spent_livestock',
#  'lvl1_money_spent_skimmer',
#  'lvl1_money_spent_sign',
#  'lvl1_money_spent_road',
#  'lvl1_min_num_home_in_play',
#  'lvl1_max_num_home_in_play',
#  'lvl1_min_num_food_in_play',
#  'lvl1_max_num_food_in_play',
#  'lvl1_min_num_farm_in_play',
#  'lvl1_max_num_farm_in_play',
#  'lvl1_min_num_fertilizer_in_play',
#  'lvl1_max_num_fertilizer_in_play',
#  'lvl1_min_num_livestock_in_play',
#  'lvl1_max_num_livestock_in_play',
#  'lvl1_min_num_skimmer_in_play',
#  'lvl1_max_num_skimmer_in_play',
#  'lvl1_min_num_sign_in_play',
#  'lvl1_max_num_sign_in_play',
#  'lvl1_min_num_road_in_play',
#  'lvl1_max_num_road_in_play',
#  'lvl1_min_num_water_in_play',
#  'lvl1_max_num_water_in_play',
#  'lvl1_min_num_poop_in_play',
#  'lvl1_max_num_poop_in_play',
#  'lvl1_min_num_milk_in_play',
#  'lvl1_max_num_milk_in_play',
#  'lvl1_avg_num_tiles_hovered_before_placing_home',
#  'lvl1_avg_num_tiles_hovered_before_placing_food',
#  'lvl1_avg_num_tiles_hovered_before_placing_farm',
#  'lvl1_avg_num_tiles_hovered_before_placing_fertilizer',
#  'lvl1_avg_num_tiles_hovered_before_placing_livestock',
#  'lvl1_avg_num_tiles_hovered_before_placing_skimmer',
#  'lvl1_avg_num_tiles_hovered_before_placing_sign',
#  'lvl1_avg_num_tiles_hovered_before_placing_road',
#  'lvl1_percent_compliance_with_a_tutorial_within_x_seconds',
#  'lvl1_avg_distance_between_poop_placement_and_lake',
#  'lvl1_avg_avg_distance_between_buildings',
#  'lvl1_percent_building_a_farm_on_highest_nutrition_tile',
#  'lvl1_percent_placing_fertilizer_on_lowest_nutrient_farm',
#  'lvl1_build_sequences',
#  'lvl1_count_inspect_tile',
#  'lvl1_count_open_achievements',
#  'lvl1_count_open_shop',
#  'lvl1_count_deaths',
#  'lvl1_count_encounter_tutorial',
#  'lvl1_count_skips',
#  'lvl1_avg_time_per_blurb',
#  'lvl1_time_in_nutrition_view',
#  'lvl1_time_in_game_speed_pause',
#  'lvl1_time_in_game_speed_play',
#  'lvl1_time_in_game_speed_fast',
#  'lvl1_time_in_game_speed_vfast',
#  'lvl1_count_change_item_mark',
#  'lvl1_count_change_tile_mark',
#  'lvl1_max_num_food_marked_sell',
#  'lvl1_max_num_food_marked_use',
#  'lvl1_max_num_food_marked_feed',
#  'lvl1_max_num_milk_marked_sell',
#  'lvl1_max_num_milk_marked_use',
#  'lvl1_max_num_poop_marked_sell',
#  'lvl1_max_num_poop_marked_use',
#  'lvl1_max_percent_food_marked_sell',
#  'lvl1_max_percent_food_marked_use',
#  'lvl1_max_percent_food_marked_feed',
#  'lvl1_max_percent_milk_marked_sell',
#  'lvl1_max_percent_milk_marked_use',
#  'lvl1_max_percent_poop_marked_sell',
#  'lvl1_max_percent_poop_marked_use',
#  'lvl1_min_num_food_marked_sell',
#  'lvl1_min_num_food_marked_use',
#  'lvl1_min_num_food_marked_feed',
#  'lvl1_min_num_milk_marked_sell',
#  'lvl1_min_num_milk_marked_use',
#  'lvl1_min_num_poop_marked_sell',
#  'lvl1_min_num_poop_marked_use',
#  'lvl1_min_percent_food_marked_sell',
#  'lvl1_min_percent_food_marked_use',
#  'lvl1_min_percent_food_marked_feed',
#  'lvl1_min_percent_milk_marked_sell',
#  'lvl1_min_percent_milk_marked_use',
#  'lvl1_min_percent_poop_marked_sell',
#  'lvl1_min_percent_poop_marked_use',
#  'lvl1_max_num_per_capita_food_marked_sell',
#  'lvl1_min_num_per_capita_food_marked_sell',
#  'lvl1_max_num_per_capita_food_marked_use',
#  'lvl1_min_num_per_capita_food_marked_use',
#  'lvl1_max_num_per_capita_food_marked_feed',
#  'lvl1_min_num_per_capita_food_marked_feed',
#  'lvl1_max_num_per_capita_milk_marked_sell',
#  'lvl1_min_num_per_capita_milk_marked_sell',
#  'lvl1_max_num_per_capita_milk_marked_use',
#  'lvl1_min_num_per_capita_milk_marked_use',
#  'lvl1_max_num_per_capita_poop_marked_sell',
#  'lvl1_min_num_per_capita_poop_marked_sell',
#  'lvl1_max_num_per_capita_poop_marked_use',
#  'lvl1_min_num_per_capita_poop_marked_use',
#  'lvl1_count_fullness_motivated_txt_emotes_per_capita',
#  'lvl1_count_fullness_desperate_txt_emotes_per_capita',
#  'lvl1_count_energy_desperate_txt_emotes_per_capita',
#  'lvl1_count_joy_motivated_txt_emotes_per_capita',
#  'lvl1_count_joy_desperate_txt_emotes_per_capita',
#  'lvl1_count_puke_txt_emotes_per_capita',
#  'lvl1_count_yum_txt_emotes_per_capita',
#  'lvl1_count_tired_txt_emotes_per_capita',
#  'lvl1_count_happy_txt_emotes_per_capita',
#  'lvl1_count_swim_txt_emotes_per_capita',
#  'lvl1_count_sale_txt_emotes_per_capita',
#  'lvl1_percent_positive_emotes',
#  'lvl1_percent_negative_emotes',
#  'lvl1_percent_neutral_emotes',
#  'lvl1_money_earned',
#  'lvl1_total_positive_emotes',
#  'lvl1_total_negative_emotes',
#  'lvl1_total_neutral_emotes',
#  'lvl1_max_avg_lake_nutrition',
#  'lvl1_min_avg_lake_nutrition',
#  'lvl1_count_farmfails',
#  'lvl1_count_blooms',
#  'lvl1_max_num_lake_tiles_in_bloom',
#  'lvl1_min_num_lake_tiles_in_bloom',
#  'lvl1_count_food_produced',
#  'lvl1_count_milk_produced',
#  'lvl1_count_poop_produced',
#  'lvl2_EventCount',
#  'lvl2_ActiveEventCount',
#  'lvl2_durationInSecs',
#  'lvl2_count_gamestate_logs',
#  'lvl2_count_achievements',
#  'lvl2_count_buy_home',
#  'lvl2_count_buy_food',
#  'lvl2_count_buy_farm',
#  'lvl2_count_buy_fertilizer',
#  'lvl2_count_buy_livestock',
#  'lvl2_count_buy_skimmer',
#  'lvl2_count_buy_sign',
#  'lvl2_count_buy_road',
#  'lvl2_money_spent',
#  'lvl2_money_spent_home',
#  'lvl2_money_spent_food',
#  'lvl2_money_spent_farm',
#  'lvl2_money_spent_fertilizer',
#  'lvl2_money_spent_livestock',
#  'lvl2_money_spent_skimmer',
#  'lvl2_money_spent_sign',
#  'lvl2_money_spent_road',
#  'lvl2_min_num_home_in_play',
#  'lvl2_max_num_home_in_play',
#  'lvl2_min_num_food_in_play',
#  'lvl2_max_num_food_in_play',
#  'lvl2_min_num_farm_in_play',
#  'lvl2_max_num_farm_in_play',
#  'lvl2_min_num_fertilizer_in_play',
#  'lvl2_max_num_fertilizer_in_play',
#  'lvl2_min_num_livestock_in_play',
#  'lvl2_max_num_livestock_in_play',
#  'lvl2_min_num_skimmer_in_play',
#  'lvl2_max_num_skimmer_in_play',
#  'lvl2_min_num_sign_in_play',
#  'lvl2_max_num_sign_in_play',
#  'lvl2_min_num_road_in_play',
#  'lvl2_max_num_road_in_play',
#  'lvl2_min_num_water_in_play',
#  'lvl2_max_num_water_in_play',
#  'lvl2_min_num_poop_in_play',
#  'lvl2_max_num_poop_in_play',
#  'lvl2_min_num_milk_in_play',
#  'lvl2_max_num_milk_in_play',
#  'lvl2_avg_num_tiles_hovered_before_placing_home',
#  'lvl2_avg_num_tiles_hovered_before_placing_food',
#  'lvl2_avg_num_tiles_hovered_before_placing_farm',
#  'lvl2_avg_num_tiles_hovered_before_placing_fertilizer',
#  'lvl2_avg_num_tiles_hovered_before_placing_livestock',
#  'lvl2_avg_num_tiles_hovered_before_placing_skimmer',
#  'lvl2_avg_num_tiles_hovered_before_placing_sign',
#  'lvl2_avg_num_tiles_hovered_before_placing_road',
#  'lvl2_percent_compliance_with_a_tutorial_within_x_seconds',
#  'lvl2_avg_distance_between_poop_placement_and_lake',
#  'lvl2_avg_avg_distance_between_buildings',
#  'lvl2_percent_building_a_farm_on_highest_nutrition_tile',
#  'lvl2_percent_placing_fertilizer_on_lowest_nutrient_farm',
#  'lvl2_build_sequences',
#  'lvl2_count_inspect_tile',
#  'lvl2_count_open_achievements',
#  'lvl2_count_open_shop',
#  'lvl2_count_deaths',
#  'lvl2_count_encounter_tutorial',
#  'lvl2_count_skips',
#  'lvl2_avg_time_per_blurb',
#  'lvl2_time_in_nutrition_view',
#  'lvl2_time_in_game_speed_pause',
#  'lvl2_time_in_game_speed_play',
#  'lvl2_time_in_game_speed_fast',
#  'lvl2_time_in_game_speed_vfast',
#  'lvl2_count_change_item_mark',
#  'lvl2_count_change_tile_mark',
#  'lvl2_max_num_food_marked_sell',
#  'lvl2_max_num_food_marked_use',
#  'lvl2_max_num_food_marked_feed',
#  'lvl2_max_num_milk_marked_sell',
#  'lvl2_max_num_milk_marked_use',
#  'lvl2_max_num_poop_marked_sell',
#  'lvl2_max_num_poop_marked_use',
#  'lvl2_max_percent_food_marked_sell',
#  'lvl2_max_percent_food_marked_use',
#  'lvl2_max_percent_food_marked_feed',
#  'lvl2_max_percent_milk_marked_sell',
#  'lvl2_max_percent_milk_marked_use',
#  'lvl2_max_percent_poop_marked_sell',
#  'lvl2_max_percent_poop_marked_use',
#  'lvl2_min_num_food_marked_sell',
#  'lvl2_min_num_food_marked_use',
#  'lvl2_min_num_food_marked_feed',
#  'lvl2_min_num_milk_marked_sell',
#  'lvl2_min_num_milk_marked_use',
#  'lvl2_min_num_poop_marked_sell',
#  'lvl2_min_num_poop_marked_use',
#  'lvl2_min_percent_food_marked_sell',
#  'lvl2_min_percent_food_marked_use',
#  'lvl2_min_percent_food_marked_feed',
#  'lvl2_min_percent_milk_marked_sell',
#  'lvl2_min_percent_milk_marked_use',
#  'lvl2_min_percent_poop_marked_sell',
#  'lvl2_min_percent_poop_marked_use',
#  'lvl2_max_num_per_capita_food_marked_sell',
#  'lvl2_min_num_per_capita_food_marked_sell',
#  'lvl2_max_num_per_capita_food_marked_use',
#  'lvl2_min_num_per_capita_food_marked_use',
#  'lvl2_max_num_per_capita_food_marked_feed',
#  'lvl2_min_num_per_capita_food_marked_feed',
#  'lvl2_max_num_per_capita_milk_marked_sell',
#  'lvl2_min_num_per_capita_milk_marked_sell',
#  'lvl2_max_num_per_capita_milk_marked_use',
#  'lvl2_min_num_per_capita_milk_marked_use',
#  'lvl2_max_num_per_capita_poop_marked_sell',
#  'lvl2_min_num_per_capita_poop_marked_sell',
#  'lvl2_max_num_per_capita_poop_marked_use',
#  'lvl2_min_num_per_capita_poop_marked_use',
#  'lvl2_count_fullness_motivated_txt_emotes_per_capita',
#  'lvl2_count_fullness_desperate_txt_emotes_per_capita',
#  'lvl2_count_energy_desperate_txt_emotes_per_capita',
#  'lvl2_count_joy_motivated_txt_emotes_per_capita',
#  'lvl2_count_joy_desperate_txt_emotes_per_capita',
#  'lvl2_count_puke_txt_emotes_per_capita',
#  'lvl2_count_yum_txt_emotes_per_capita',
#  'lvl2_count_tired_txt_emotes_per_capita',
#  'lvl2_count_happy_txt_emotes_per_capita',
#  'lvl2_count_swim_txt_emotes_per_capita',
#  'lvl2_count_sale_txt_emotes_per_capita',
#  'lvl2_percent_positive_emotes',
#  'lvl2_percent_negative_emotes',
#  'lvl2_percent_neutral_emotes',
#  'lvl2_money_earned',
#  'lvl2_total_positive_emotes',
#  'lvl2_total_negative_emotes',
#  'lvl2_total_neutral_emotes',
#  'lvl2_max_avg_lake_nutrition',
#  'lvl2_min_avg_lake_nutrition',
#  'lvl2_count_farmfails',
#  'lvl2_count_blooms',
#  'lvl2_max_num_lake_tiles_in_bloom',
#  'lvl2_min_num_lake_tiles_in_bloom',
#  'lvl2_count_food_produced',
#  'lvl2_count_milk_produced',
#  'lvl2_count_poop_produced',
#  'sess_count_achievements',
#  'sess_count_encounter_tutorial',
#  'sess_count_skips',
#  'sess_count_gamestate_logs',
#  'sess_count_buy_home',
#  'sess_count_buy_food',
#  'sess_count_buy_farm',
#  'sess_count_buy_fertilizer',
#  'sess_count_buy_livestock',
#  'sess_count_buy_skimmer',
#  'sess_count_buy_sign',
#  'sess_count_buy_road',
#  'sess_money_spent_home',
#  'sess_money_spent_food',
#  'sess_money_spent_farm',
#  'sess_money_spent_fertilizer',
#  'sess_money_spent_livestock',
#  'sess_money_spent_skimmer',
#  'sess_money_spent_sign',
#  'sess_money_spent_road',
#  'sess_count_change_item_mark',
#  'sess_count_change_tile_mark',
#  'sess_time_to_exist_achievement',
#  'sess_time_to_group_achievement',
#  'sess_time_to_town_achievement',
#  'sess_time_to_city_achievement',
#  'sess_time_to_farmer_achievement',
#  'sess_time_to_farmers_achievement',
#  'sess_time_to_farmtown_achievement',
#  'sess_time_to_megafarm_achievement',
#  'sess_time_to_paycheck_achievement',
#  'sess_time_to_thousandair_achievement',
#  'sess_time_to_stability_achievement',
#  'sess_time_to_riches_achievement',
#  'sess_time_to_bloom_achievement',
#  'sess_time_to_bigbloom_achievement',
#  'sess_time_to_hugebloom_achievement',
#  'sess_time_to_massivebloom_achievement',
#  'sess_time_to_another_death_tutorial',
#  'sess_time_to_another_member_tutorial',
#  'sess_time_to_bloom_tutorial',
#  'sess_time_to_build_a_farm_tutorial',
#  'sess_time_to_build_a_house_tutorial',
#  'sess_time_to_buy_fertilizer_tutorial',
#  'sess_time_to_buy_food_tutorial',
#  'sess_time_to_buy_livestock_tutorial',
#  'sess_time_to_death_tutorial',
#  'sess_time_to_end_life_tutorial',
#  'sess_time_to_extra_life_tutorial',
#  'sess_time_to_final_death_tutorial',
#  'sess_time_to_flooded_fertilizer_tutorial',
#  'sess_time_to_gross_tutorial',
#  'sess_time_to_gross_again_tutorial',
#  'sess_time_to_livestock_tutorial',
#  'sess_time_to_long_travel_tutorial',
#  'sess_time_to_low_nutrients_tutorial',
#  'sess_time_to_mass_sadness_tutorial',
#  'sess_time_to_poop_tutorial',
#  'sess_time_to_rain_tutorial',
#  'sess_time_to_sell_food_tutorial',
#  'sess_time_to_successful_harvest_tutorial',
#  'sess_time_to_timewarp_tutorial',
#  'sess_time_to_unattended_farm_tutorial',
#  'sess_time_to_unused_fertilizer_tutorial',
#  'build_a_house_compliance_interval',
#  'buy_food_compliance_interval',
#  'build_a_farm_compliance_interval',
#  'timewarp_compliance_interval',
#  'sell_food_compliance_interval',
#  'buy_fertilizer_compliance_interval',
#  'buy_livestock_compliance_interval',
#  'sess_avg_num_tiles_hovered_before_placing_home',
#  'sess_avg_num_tiles_hovered_before_placing_food',
#  'sess_avg_num_tiles_hovered_before_placing_farm',
#  'sess_avg_num_tiles_hovered_before_placing_fertilizer',
#  'sess_avg_num_tiles_hovered_before_placing_livestock',
#  'sess_avg_num_tiles_hovered_before_placing_skimmer',
#  'sess_avg_num_tiles_hovered_before_placing_sign',
#  'sess_avg_num_tiles_hovered_before_placing_road',
#  'sess_avg_time_per_blurb_in_another_death_tutorial',
#  'sess_avg_time_per_blurb_in_another_member_tutorial',
#  'sess_avg_time_per_blurb_in_bloom_tutorial',
#  'sess_avg_time_per_blurb_in_build_a_farm_tutorial',
#  'sess_avg_time_per_blurb_in_build_a_house_tutorial',
#  'sess_avg_time_per_blurb_in_buy_fertilizer_tutorial',
#  'sess_avg_time_per_blurb_in_buy_food_tutorial',
#  'sess_avg_time_per_blurb_in_buy_livestock_tutorial',
#  'sess_avg_time_per_blurb_in_death_tutorial',
#  'sess_avg_time_per_blurb_in_end_life_tutorial',
#  'sess_avg_time_per_blurb_in_extra_life_tutorial',
#  'sess_avg_time_per_blurb_in_final_death_tutorial',
#  'sess_avg_time_per_blurb_in_flooded_fertilizer_tutorial',
#  'sess_avg_time_per_blurb_in_gross_tutorial',
#  'sess_avg_time_per_blurb_in_gross_again_tutorial',
#  'sess_avg_time_per_blurb_in_livestock_tutorial',
#  'sess_avg_time_per_blurb_in_long_travel_tutorial',
#  'sess_avg_time_per_blurb_in_low_nutrients_tutorial',
#  'sess_avg_time_per_blurb_in_mass_sadness_tutorial',
#  'sess_avg_time_per_blurb_in_poop_tutorial',
#  'sess_avg_time_per_blurb_in_rain_tutorial',
#  'sess_avg_time_per_blurb_in_sell_food_tutorial',
#  'sess_avg_time_per_blurb_in_successful_harvest_tutorial',
#  'sess_avg_time_per_blurb_in_timewarp_tutorial',
#  'sess_avg_time_per_blurb_in_unattended_farm_tutorial',
#  'sess_avg_time_per_blurb_in_unused_fertilizer_tutorial',
#  'sess_time_to_first_home',
#  'sess_time_to_first_food',
#  'sess_time_to_first_farm',
#  'sess_time_to_first_fertilizer',
#  'sess_time_to_first_livestock',
#  'sess_time_to_first_skimmer',
#  'sess_time_to_first_sign',
#  'sess_time_to_first_road',
#  'sess_avg_time_per_blurb',
#  'sess_count_food_produced',
#  'sess_count_milk_produced',
#  'sess_count_poop_produced',
#  'sess_money_earned',
#  'sess_money_spent',
#  'sess_time_in_nutrition_view',
#  'sess_time_in_game_speed_pause',
#  'sess_time_in_game_speed_play',
#  'sess_time_in_game_speed_fast',
#  'sess_time_in_game_speed_vfast',
#  'sess_max_num_per_capita_food_marked_sell',
#  'sess_max_num_per_capita_food_marked_use',
#  'sess_max_num_per_capita_food_marked_feed',
#  'sess_max_num_per_capita_milk_marked_sell',
#  'sess_max_num_per_capita_milk_marked_use',
#  'sess_max_num_per_capita_poop_marked_sell',
#  'sess_max_num_per_capita_poop_marked_use',
#  'sess_min_num_per_capita_food_marked_sell',
#  'sess_min_num_per_capita_food_marked_use',
#  'sess_min_num_per_capita_food_marked_feed',
#  'sess_min_num_per_capita_milk_marked_sell',
#  'sess_min_num_per_capita_milk_marked_use',
#  'sess_min_num_per_capita_poop_marked_sell',
#  'sess_min_num_per_capita_poop_marked_use',
#  'sess_max_num_food_marked_sell',
#  'sess_max_num_food_marked_use',
#  'sess_max_num_food_marked_feed',
#  'sess_max_num_milk_marked_sell',
#  'sess_max_num_milk_marked_use',
#  'sess_max_num_poop_marked_sell',
#  'sess_max_num_poop_marked_use',
#  'sess_max_percent_food_marked_sell',
#  'sess_max_percent_food_marked_use',
#  'sess_max_percent_food_marked_feed',
#  'sess_max_percent_milk_marked_sell',
#  'sess_max_percent_milk_marked_use',
#  'sess_max_percent_poop_marked_sell',
#  'sess_max_percent_poop_marked_use',
#  'sess_min_num_food_marked_sell',
#  'sess_min_num_food_marked_use',
#  'sess_min_num_food_marked_feed',
#  'sess_min_num_milk_marked_sell',
#  'sess_min_num_milk_marked_use',
#  'sess_min_num_poop_marked_sell',
#  'sess_min_num_poop_marked_use',
#  'sess_min_percent_food_marked_sell',
#  'sess_min_percent_food_marked_use',
#  'sess_min_percent_food_marked_feed',
#  'sess_min_percent_milk_marked_sell',
#  'sess_min_percent_milk_marked_use',
#  'sess_min_percent_poop_marked_sell',
#  'sess_min_percent_poop_marked_use',
#  'sess_min_num_home_in_play',
#  'sess_max_num_home_in_play',
#  'sess_min_num_food_in_play',
#  'sess_max_num_food_in_play',
#  'sess_min_num_farm_in_play',
#  'sess_max_num_farm_in_play',
#  'sess_min_num_fertilizer_in_play',
#  'sess_max_num_fertilizer_in_play',
#  'sess_min_num_livestock_in_play',
#  'sess_max_num_livestock_in_play',
#  'sess_min_num_skimmer_in_play',
#  'sess_max_num_skimmer_in_play',
#  'sess_min_num_sign_in_play',
#  'sess_max_num_sign_in_play',
#  'sess_min_num_road_in_play',
#  'sess_max_num_road_in_play',
#  'sess_min_num_water_in_play',
#  'sess_max_num_water_in_play',
#  'sess_min_num_poop_in_play',
#  'sess_max_num_poop_in_play',
#  'sess_min_num_milk_in_play',
#  'sess_max_num_milk_in_play',
#  'sess_count_fullness_motivated_txt_emotes_per_capita',
#  'sess_count_fullness_desperate_txt_emotes_per_capita',
#  'sess_count_energy_desperate_txt_emotes_per_capita',
#  'sess_count_joy_motivated_txt_emotes_per_capita',
#  'sess_count_joy_desperate_txt_emotes_per_capita',
#  'sess_count_puke_txt_emotes_per_capita',
#  'sess_count_yum_txt_emotes_per_capita',
#  'sess_count_tired_txt_emotes_per_capita',
#  'sess_count_happy_txt_emotes_per_capita',
#  'sess_count_swim_txt_emotes_per_capita',
#  'sess_count_sale_txt_emotes_per_capita',
#  'sess_percent_positive_emotes',
#  'sess_percent_negative_emotes',
#  'sess_percent_neutral_emotes',
#  'sess_total_positive_emotes',
#  'sess_total_negative_emotes',
#  'sess_total_neutral_emotes',
#  'sess_avg_distance_between_poop_placement_and_lake',
#  'sess_avg_avg_distance_between_buildings',
#  'sess_count_farmfails',
#  'sess_max_avg_lake_nutrition',
#  'sess_min_avg_lake_nutrition',
#  'sess_count_blooms',
#  'sess_count_inspect_tile',
#  'sess_count_open_achievements',
#  'sess_count_open_shop',
#  'sess_count_deaths',
#  'sess_percent_building_a_farm_on_highest_nutrition_tile',
#  'sess_percent_placing_fertilizer_on_lowest_nutrient_farm',
#  'sess_EventCount',
#  'sess_ActiveEventCount',
#  'continue',
#  'language',
#  'audio',
#  'fullscreen',
#  'version',
#  'debug',
#  'num_play',
#  'persistentSessionID',
#  'sessDuration']

# %% [markdown]
# ### Drop Continues

# %%
df = df.drop(df[df['save_code'] != '0'].index)
print(df.shape)
df.head()
# Out:
# (241, 380)
#                    lvl0_EventCount  lvl0_count_clicks  lvl0_count_hovers  \
# sessionID
# 19110000090781600               34               26.0                6.0
# 19110012454548376               43               36.0                5.0
# 19110013234266620                2                NaN                NaN
# 19110014392453668                2                NaN                NaN
# 19110016345644932               40               28.0               10.0
#
#                    lvl0_avgTimePerTextBox  lvl0_time_in_level  \
# sessionID
# 19110000090781600                1.672167              63.535
# 19110012454548376                1.545500              73.820
# 19110013234266620                     NaN               0.002
# 19110014392453668                     NaN               0.002
# 19110016345644932                1.154714             200.637
#
#                    lvl0_meaningful_action_count  lvl0_words_per_second  \
# sessionID
# 19110000090781600                           3.0               3.970336
# 19110012454548376                           4.0               6.184182
# 19110013234266620                           NaN                    NaN
# 19110014392453668                           NaN                    NaN
# 19110016345644932                           4.0               5.354636
#
#                    lvl0_count_notebook_uses  lvl0_avg_time_between_clicks  \
# sessionID
# 19110000090781600                       NaN                      2.096680
# 19110012454548376                       NaN                      1.584343
# 19110013234266620                       NaN                           NaN
# 19110014392453668                       NaN                           NaN
# 19110016345644932                       NaN                      1.410185
#
#                    lvl1_EventCount  ...  sess_avgTimePerWord  \
# sessionID                           ...
# 19110000090781600             30.0  ...                    0
# 19110012454548376            114.0  ...                    0
# 19110013234266620              NaN  ...                    0
# 19110014392453668              NaN  ...                    0
# 19110016345644932             34.0  ...                    0
#
#                    sess_avgTimePerTextBox  sess_stDevTimePerTextBox  \
# sessionID
# 19110000090781600               16.005742                         0
# 19110012454548376                7.371897                         0
# 19110013234266620                4.979176                         0
# 19110014392453668                6.194067                         0
# 19110016345644932                5.708855                         0
#
#                    sess_words_per_second  sess_count_notebook_uses  \
# sessionID
# 19110000090781600               4.125283                         8
# 19110012454548376               7.551905                        11
# 19110013234266620               9.855149                         6
# 19110014392453668               6.349095                         1
# 19110016345644932               6.087589                         2
#
#                    sess_avg_time_between_clicks  save_code  music  hq  \
# sessionID
# 19110000090781600                    161.139635          0      1   0
# 19110012454548376                      1.610426          0      1   1
# 19110013234266620                      1.309599          0      1   0
# 19110014392453668                      1.576921          0      1   0
# 19110016345644932                      2.864502          0      1   0
#
#                    fullscreen
# sessionID
# 19110000090781600           0
# 19110012454548376        True
# 19110013234266620           0
# 19110014392453668           0
# 19110016345644932           0
#
# [5 rows x 380 columns]

# %%
def output_level_histogram(fname_base, xlabel, **kwargs):
    # set parameters
    output_file = os.path.join('jowilder_graphs', f'{date.today().strftime("%Y%m%d")}_{fname_base}.jpg')
    aggregate_fname = kwargs.get("aggregate_fname") or 'sess_'+fname_base
    xlim = kwargs.get("xlim") or None
    agg_xlim = kwargs.get("agg_xlim") or None
    zscore_cutoff = kwargs.get("zscore_cutoff") or 3
    max_x = kwargs.get("max_x") or None
    max_x_agg = kwargs.get("max_x_agg") or  None
    params = {"Max zscore kept (others data points thrown out as outliers)": zscore_cutoff,
            "Max X value kept - Level": max_x,
            "Max X value kept - Aggregate": max_x_agg,
            "Graph right cutoff - Level": xlim,
            "Graph right cutoff -  Aggregate": agg_xlim
             }
    lvl_range = range(23)


    # drop if NA for any
    feat_col_names = [f'lvl{lvl}_{fname_base}' for lvl in lvl_range] + [f'sess_words_per_second']
    hist_df = df.dropna(subset=feat_col_names)
    
    def get_histogram_level_feat(fname_base, lvl,max_x=None):
        get_histogram_feat(f'lvl{lvl}_{fname_base}',f'Level {lvl}',max_x=max_x)
                               
    def get_histogram_feat(fname,title,max_x=None):                           
        feat_df = hist_df[[fname]]
        if max_x:
            feat_df = feat_df[feat_df[fname] <= max_x]
        feat_df_no_outliers = feat_df[(np.abs(stats.zscore(feat_df)) < zscore_cutoff).all(axis=1)]
        feat_list = list((feat_df_no_outliers)[fname])
                               
        plt.xlabel(xlabel)
        plt.title(title)
        plt.ylabel(f'number of players (n={len(feat_list)})')
        plt.hist(feat_list, bins=30)

    fig = plt.figure(figsize=(10,30),dpi=160)
    fig.suptitle(fname_base,fontsize=24)
    fig.subplots_adjust(hspace=0.6, wspace=0.4)
    for i in lvl_range:
        fig.add_subplot(13,2,i+1)
        get_histogram_level_feat(fname_base,i,max_x=max_x)
        if xlim:
            plt.xlim((0,xlim))
    fig.add_subplot(10,2,20)
    get_histogram_feat(aggregate_fname, 'Aggregate',max_x=max_x_agg)
    if agg_xlim:
        plt.xlim((0,agg_xlim))
                               
    plt.tight_layout(rect=[0,0.03,1,0.95])
    arg_string = "\n".join(f"{k}: {v}" for k,v in params.items() if v)
    fig.text(.03,.95,f'Generated on {date.today().strftime("%m/%d/%Y")}.\n{arg_string}')
    plt.show()
    fig.savefig(output_file)
                               
output_level_histogram('count_notebook_uses','number of notebook uses',zscore_cutoff=6)
# Out:
# /Users/johnmccloskey/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:2281: RuntimeWarning: invalid value encountered in true_divide
#   return (a - mns) / sstd
# /Users/johnmccloskey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: RuntimeWarning: invalid value encountered in less
# /Users/johnmccloskey/anaconda3/lib/python3.7/site-packages/matplotlib/tight_layout.py:340: UserWarning: tight_layout not applied: number of rows in subplot specifications mustbe multiples of one another.
#   warnings.warn('tight_layout not applied: '

# %%
output_level_histogram('time_in_level','seconds',aggregate_fname='sessDuration',max_x=1000, max_x_agg=5000)

# %%
output_level_histogram('EventCount','number of logged events')

# %%
output_level_histogram('avg_time_between_clicks', 'seconds')

# %%
output_level_histogram('meaningful_action_count', 'number of meaningful actions')

# %%
output_level_histogram('count_notebook_uses', 'number of meaningful actions')
# Out:
# /Users/johnmccloskey/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:28: RuntimeWarning: invalid value encountered in less
